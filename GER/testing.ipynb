# %%
class Equipment:
    def __init__(self, model, manufacturer, serial_number, fa_number, item_number, cost, rental_rate, week_break):
        """Create an instance of the Equipment Class with the given attributes."""
        self.model = model
        self.manufacturer = manufacturer
        self.serial_number = serial_number
        self.fa_number = fa_number
        self.item_number = item_number
        self.cost = cost
        self.rental_rate = rental_rate
        self.week_break` = week_break
        
    def rental_cost(self, rate, days=1):
